# %%
# Install seaborn
# If this line gives an error, go back to command prompt and run "conda install pip" and then try this step again
# !pip install seaborn
# Out:
# Requirement already satisfied (use --upgrade to upgrade): seaborn in /Users/arthurconner/anaconda/lib/python2.7/site-packages
# Cleaning up...

# %%
# Standard imports for data analysis packages in Python
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image

# This enables inline Plots
# %matplotlib inline

# Limit rows displayed in notebook
pd.set_option('display.max_rows', 10)
pd.set_option('display.precision', 2)

# %%
print 'Pandas Version: ', pd.__version__
print 'Numpy Version: ', np.__version__
# Out:
# Pandas Version:  0.14.1
# Numpy Version:  1.9.1

# %% [markdown]
# # Pandas DataFrame
#
# Think of DataFrame as a Table with Columns.  This is the workhorse of everything you will do with data analysis.  Learning Pandas and its functions can be challenging, but stick with it and ask questions.
#
# Who uses Pandas - Almost everyone who uses Python for Data Analysis - Netflix, Airbnb, Uber, Meetup.com to name a few.

# %% [markdown]
# Kaggle Titanic Dataset:
# =======================
#
# * Source: http://www.kaggle.com/c/titanic-gettingStarted/data

# %%
# Let's explore Titanic Dataset
titanic = pd.read_csv('http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.csv')

# %%
titanic.head(5)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#     age  sibsp  parch  ticket   fare    cabin embarked boat  body  \
# 0  29.0      0      0   24160  211.3       B5        S    2   NaN
# 1   0.9      1      2  113781  151.6  C22 C26        S   11   NaN
# 2   2.0      1      2  113781  151.6  C22 C26        S  NaN   NaN
# 3  30.0      1      2  113781  151.6  C22 C26        S  NaN   135
# 4  25.0      1      2  113781  151.6  C22 C26        S  NaN   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
# Look at the Columns, data types, memory usage, null values
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
# pclass       1309 non-null int64
# survived     1309 non-null int64
# name         1309 non-null object
# sex          1309 non-null object
# age          1046 non-null float64
# sibsp        1309 non-null int64
# parch        1309 non-null int64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# boat         486 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(3), int64(4), object(7)

# %%
# View Distribution
titanic.describe()
# Out:
#        pclass  survived     age   sibsp   parch    fare   body
# count  1309.0    1309.0  1046.0  1309.0  1309.0  1308.0  121.0
# mean      2.3       0.4    29.9     0.5     0.4    33.3  160.8
# std       0.8       0.5    14.4     1.0     0.9    51.8   97.7
# min       1.0       0.0     0.2     0.0     0.0     0.0    1.0
# 25%       2.0       0.0    21.0     0.0     0.0     7.9   72.0
# 50%       3.0       0.0    28.0     0.0     0.0    14.5  155.0
# 75%       3.0       1.0    39.0     1.0     0.0    31.3  256.0
# max       3.0       1.0    80.0     8.0     9.0   512.3  328.0

# %%
titanic.columns
# Out:
# Index([u'pclass', u'survived', u'name', u'sex', u'age', u'sibsp', u'parch', u'ticket', u'fare', u'cabin', u'embarked', u'boat', u'body', u'home.dest'], dtype='object')

# %%
titanic.rename(columns={'sex': 'gender'}, inplace=True)

# %%
# So What is a Pandas Dataframe
# What is a Pandas DataFrame
Image(filename='images/dataframe.png')

# %%
# show only that survived
titanic[titanic.survived == 1]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1277       3         1                             Vartanian, Mr. David
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
#
#       gender   age  sibsp  parch  ticket   fare    cabin embarked   boat  \
# 0     female  29.0      0      0   24160  211.3       B5        S      2
# 1       male   0.9      1      2  113781  151.6  C22 C26        S     11
# 5       male  48.0      0      0   19952   26.6      E12        S      3
# 6     female  63.0      1      0   13502   78.0       D7        S     10
# 8     female  53.0      2      0   11769   51.5     C101        S      D
# ...      ...   ...    ...    ...     ...    ...      ...      ...    ...
# 1261  female  63.0      0      0    4134    9.6      NaN        S     15
# 1277    male  22.0      0      0    2658    7.2      NaN        C  13 15
# 1286  female  38.0      0      0    2688    7.2      NaN        C      C
# 1290  female  47.0      1      0  363272    7.0      NaN        S    NaN
# 1300  female  15.0      1      0    2659   14.5      NaN        C    NaN
#
#       body                        home.dest
# 0      NaN                     St Louis, MO
# 1      NaN  Montreal, PQ / Chesterville, ON
# 5      NaN                     New York, NY
# 6      NaN                       Hudson, NY
# 8      NaN              Bayside, Queens, NY
# ...    ...                              ...
# 1261   NaN                              NaN
# 1277   NaN                              NaN
# 1286   NaN                              NaN
# 1290   NaN                              NaN
# 1300   NaN                              NaN
#
# [500 rows x 14 columns]

# %%
# unique values
titanic.gender.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# How many Survived?
titanic['survived'].value_counts()
# Out:
# 0    809
# 1    500
# dtype: int64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
# pclass       1309 non-null int64
# survived     1309 non-null int64
# name         1309 non-null object
# gender       1309 non-null object
# age          1046 non-null float64
# sibsp        1309 non-null int64
# parch        1309 non-null int64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# boat         486 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(3), int64(4), object(7)

# %%
# Let's identify the missing age rows 
 titanic.age[pd.isnull(titanic.age)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-553dd24ea8d7> in <module>()
#       1 # Let's identify the missing age rows
# ----> 2 titantic['age_computed'] = titanic.age[pd.isnull(titanic.age)]
#
# NameError: name 'titantic' is not defined

# %%
# Age - fix null values
titanic['age_computed'] = titanic.age.fillna(titanic.age.mean())

# %%
# Did the inplace get us again?
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
# pclass          1309 non-null int64
# survived        1309 non-null int64
# name            1309 non-null object
# gender          1309 non-null object
# age             1046 non-null float64
# sibsp           1309 non-null int64
# parch           1309 non-null int64
# ticket          1309 non-null object
# fare            1308 non-null float64
# cabin           295 non-null object
# embarked        1307 non-null object
# boat            486 non-null object
# body            121 non-null float64
# home.dest       745 non-null object
# age_computed    1309 non-null float64
# dtypes: float64(4), int64(4), object(7)

# %%
numpy

# %%
# Distribution of Age
titanic.age.hist(bins=50)

# %%
# Distribution of Age by Gender
titanic.age.hist(by=titanic['gender'],bins=50);

# %%
# They look the same, buy see that y-axis is not the same
titanic.age.hist(by=titanic['gender'], sharey=True,bins=20);

# %%
# Did your gender make a difference in survival
titanic.gender.value_counts()

# %%
Image(filename='images/wesm_book_groupby.png')

# %%
# Groupby
titanic.groupby(['pclass', 'gender'])['survived'].agg(['sum', 'count'])
# Out:
#                sum  count
# pclass gender
# 1      female  139    144
#        male     61    179
# 2      female   94    106
#        male     25    171
# 3      female  106    216
#        male     75    493

# %%
# Show how many survivied by gender and class
class_gender_group = titanic.groupby(['pclass', 'gender'])

# %%
for k, group in class_gender_group:
    print(k)
# Out:
# (1, 'female')
# (1, 'male')
# (2, 'female')
# (2, 'male')
# (3, 'female')
# (3, 'male')

# %%
for k, group in class_gender_group:
    print(k,group)
# Out:
# ((1, 'female'),      pclass  survived                                             name  \
# 0         1         1                    Allen, Miss. Elisabeth Walton
# 2         1         0                     Allison, Miss. Helen Loraine
# 4         1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6         1         1                Andrews, Miss. Kornelia Theodosia
# 8         1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ..      ...       ...                                              ...
# 311       1         1       Wick, Mrs. George Dennick (Mary Hitchcock)
# 314       1         1     Widener, Mrs. George Dunton (Eleanor Elkins)
# 315       1         1                         Willard, Miss. Constance
# 319       1         1                        Wilson, Miss. Helen Alice
# 322       1         1                         Young, Miss. Marie Grice
#
#      gender  age  sibsp  parch    ticket   fare    cabin embarked  boat  body  \
# 0    female   29      0      0     24160  211.3       B5        S     2   NaN
# 2    female    2      1      2    113781  151.6  C22 C26        S   NaN   NaN
# 4    female   25      1      2    113781  151.6  C22 C26        S   NaN   NaN
# 6    female   63      1      0     13502   78.0       D7        S    10   NaN
# 8    female   53      2      0     11769   51.5     C101        S     D   NaN
# ..      ...  ...    ...    ...       ...    ...      ...      ...   ...   ...
# 311  female   45      1      1     36928  164.9      NaN        S     8   NaN
# 314  female   50      1      1    113503  211.5      C80        C     4   NaN
# 315  female   21      0      0    113795   26.6      NaN        S  8 10   NaN
# 319  female   31      0      0     16966  134.5  E39 E41        C     3   NaN
# 322  female   36      0      0  PC 17760  135.6      C32        C     8   NaN
#
#                            home.dest  age_computed
# 0                       St Louis, MO            29
# 2    Montreal, PQ / Chesterville, ON             2
# 4    Montreal, PQ / Chesterville, ON            25
# 6                         Hudson, NY            63
# 8                Bayside, Queens, NY            53
# ..                               ...           ...
# 311                   Youngstown, OH            45
# 314                  Elkins Park, PA            50
# 315                       Duluth, MN            21
# 319                              NaN            31
# 322    New York, NY / Washington, DC            36
#
# [144 rows x 15 columns])
# ((1, 'male'),      pclass  survived                                    name gender   age  \
# 1         1         1          Allison, Master. Hudson Trevor   male   0.9
# 3         1         0    Allison, Mr. Hudson Joshua Creighton   male  30.0
# 5         1         1                     Anderson, Mr. Harry   male  48.0
# 7         1         0                  Andrews, Mr. Thomas Jr   male  39.0
# 9         1         0                 Artagaveytia, Mr. Ramon   male  71.0
# ..      ...       ...                                     ...    ...   ...
# 316       1         0             Williams, Mr. Charles Duane   male  51.0
# 317       1         1         Williams, Mr. Richard Norris II   male  21.0
# 318       1         0  Williams-Lambert, Mr. Fletcher Fellows   male   NaN
# 320       1         1                       Woolner, Mr. Hugh   male   NaN
# 321       1         0                      Wright, Mr. George   male  62.0
#
#      sibsp  parch    ticket   fare    cabin embarked boat  body  \
# 1        1      2    113781  151.6  C22 C26        S   11   NaN
# 3        1      2    113781  151.6  C22 C26        S  NaN   135
# 5        0      0     19952   26.6      E12        S    3   NaN
# 7        0      0    112050    0.0      A36        S  NaN   NaN
# 9        0      0  PC 17609   49.5      NaN        C  NaN    22
# ..     ...    ...       ...    ...      ...      ...  ...   ...
# 316      0      1  PC 17597   61.4      NaN        C  NaN   NaN
# 317      0      1  PC 17597   61.4      NaN        C    A   NaN
# 318      0      0    113510   35.0     C128        S  NaN   NaN
# 320      0      0     19947   35.5      C52        S    D   NaN
# 321      0      0    113807   26.6      NaN        S  NaN   NaN
#
#                             home.dest  age_computed
# 1     Montreal, PQ / Chesterville, ON           0.9
# 3     Montreal, PQ / Chesterville, ON          30.0
# 5                        New York, NY          48.0
# 7                         Belfast, NI          39.0
# 9                 Montevideo, Uruguay          71.0
# ..                                ...           ...
# 316  Geneva, Switzerland / Radnor, PA          51.0
# 317  Geneva, Switzerland / Radnor, PA          21.0
# 318                   London, England          29.9
# 320                   London, England          29.9
# 321                       Halifax, NS          62.0
#
# [179 rows x 15 columns])
# ((2, 'female'),      pclass  survived                                               name  \
# 324       2         1              Abelson, Mrs. Samuel (Hannah Wizosky)
# 329       2         1  Angle, Mrs. William A (Florence "Mary" Agnes H...
# 333       2         1                            Ball, Mrs. (Ada E Hall)
# 337       2         1                  Beane, Mrs. Edward (Ethel Clarke)
# 340       2         1                        Becker, Miss. Marion Louise
# ..      ...       ...                                                ...
# 590       2         1                              West, Miss. Barbara J
# 591       2         1                       West, Miss. Constance Mirium
# 593       2         1            West, Mrs. Edwy Arthur (Ada Mary Worth)
# 598       2         1                               Wright, Miss. Marion
# 599       2         0             Yrois, Miss. Henriette ("Mrs Harbeck")
#
#      gender   age  sibsp  parch      ticket  fare cabin embarked boat  body  \
# 324  female  28.0      1      0   P/PP 3381  24.0   NaN        C   10   NaN
# 329  female  36.0      1      0      226875  26.0   NaN        S   11   NaN
# 333  female  36.0      0      0       28551  13.0     D        S   10   NaN
# 337  female  19.0      1      0        2908  26.0   NaN        S   13   NaN
# 340  female   4.0      2      1      230136  39.0    F4        S   11   NaN
# ..      ...   ...    ...    ...         ...   ...   ...      ...  ...   ...
# 590  female   0.9      1      2  C.A. 34651  27.8   NaN        S   10   NaN
# 591  female   5.0      1      2  C.A. 34651  27.8   NaN        S   10   NaN
# 593  female  33.0      1      2  C.A. 34651  27.8   NaN        S   10   NaN
# 598  female  26.0      0      0      220844  13.5   NaN        S    9   NaN
# 599  female  24.0      0      0      248747  13.0   NaN        S  NaN   NaN
#
#                                home.dest  age_computed
# 324                  Russia New York, NY          28.0
# 329                     Warwick, England          36.0
# 333     Bristol, Avon / Jacksonville, FL          36.0
# 337               Norwich / New York, NY          19.0
# 340   Guntur, India / Benton Harbour, MI           4.0
# ..                                   ...           ...
# 590                  Bournmouth, England           0.9
# 591                  Bournmouth, England           5.0
# 593                  Bournmouth, England          33.0
# 598  Yoevil, England / Cottage Grove, OR          26.0
# 599                                Paris          24.0
#
# [106 rows x 15 columns])
# ((2, 'male'),      pclass  survived                            name gender  age  sibsp  \
# 323       2         0             Abelson, Mr. Samuel   male   30      1
# 325       2         0  Aldworth, Mr. Charles Augustus   male   30      0
# 326       2         0      Andrew, Mr. Edgardo Samuel   male   18      0
# 327       2         0        Andrew, Mr. Frank Thomas   male   25      0
# 328       2         0            Angle, Mr. William A   male   34      1
# ..      ...       ...                             ...    ...  ...    ...
# 592       2         0           West, Mr. Edwy Arthur   male   36      1
# 594       2         0           Wheadon, Mr. Edward H   male   66      0
# 595       2         0  Wheeler, Mr. Edwin "Frederick"   male  NaN      0
# 596       2         1           Wilhelms, Mr. Charles   male   31      0
# 597       2         1    Williams, Mr. Charles Eugene   male  NaN      0
#
#      parch         ticket  fare cabin embarked boat  body  \
# 323      0      P/PP 3381  24.0   NaN        C  NaN   NaN
# 325      0         248744  13.0   NaN        S  NaN   NaN
# 326      0         231945  11.5   NaN        S  NaN   NaN
# 327      0     C.A. 34050  10.5   NaN        S  NaN   NaN
# 328      0         226875  26.0   NaN        S  NaN   NaN
# ..     ...            ...   ...   ...      ...  ...   ...
# 592      2     C.A. 34651  27.8   NaN        S  NaN   NaN
# 594      0     C.A. 24579  10.5   NaN        S  NaN   NaN
# 595      0  SC/PARIS 2159  12.9   NaN        S  NaN   NaN
# 596      0         244270  13.0   NaN        S    9   NaN
# 597      0         244373  13.0   NaN        S   14   NaN
#
#                                     home.dest  age_computed
# 323                       Russia New York, NY          30.0
# 325                        Bryn Mawr, PA, USA          30.0
# 326  Buenos Aires, Argentina / New Jersey, NJ          18.0
# 327            Cornwall, England Houghton, MI          25.0
# 328                          Warwick, England          34.0
# ..                                        ...           ...
# 592                       Bournmouth, England          36.0
# 594          Guernsey, England / Edgewood, RI          66.0
# 595                                       NaN          29.9
# 596                           London, England          31.0
# 597                           Harrow, England          29.9
#
# [171 rows x 15 columns])
# ((3, 'female'),       pclass  survived                                             name  \
# 603        3         1                 Abbott, Mrs. Stanton (Rosa Hunt)
# 604        3         1                      Abelseth, Miss. Karen Marie
# 607        3         1        Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 610        3         0   Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# 612        3         1                       Aks, Mrs. Sam (Leah Rosen)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#       gender   age  sibsp  parch     ticket  fare cabin embarked boat  body  \
# 603   female  35.0      1      1  C.A. 2673  20.2   NaN        S    A   NaN
# 604   female  16.0      0      0     348125   7.7   NaN        S   16   NaN
# 607   female  18.0      0      0       2657   7.2   NaN        C    C   NaN
# 610   female  40.0      1      0       7546   9.5   NaN        S  NaN   NaN
# 612   female  18.0      0      1     392091   9.3   NaN        S   13   NaN
# ...      ...   ...    ...    ...        ...   ...   ...      ...  ...   ...
# 1286  female  38.0      0      0       2688   7.2   NaN        C    C   NaN
# 1290  female  47.0      1      0     363272   7.0   NaN        S  NaN   NaN
# 1300  female  15.0      1      0       2659  14.5   NaN        C  NaN   NaN
# 1304  female  14.5      1      0       2665  14.5   NaN        C  NaN   328
# 1305  female   NaN      1      0       2665  14.5   NaN        C  NaN   NaN
#
#                         home.dest  age_computed
# 603           East Providence, RI          35.0
# 604        Norway Los Angeles, CA          16.0
# 607                Greensburg, PA          18.0
# 610             Sweden Akeley, MN          40.0
# 612   London, England Norfolk, VA          18.0
# ...                           ...           ...
# 1286                          NaN          38.0
# 1290                          NaN          47.0
# 1300                          NaN          15.0
# 1304                          NaN          14.5
# 1305                          NaN          29.9
#
# [216 rows x 15 columns])
# ((3, 'male'),       pclass  survived                                      name gender   age  \
# 600        3         0                       Abbing, Mr. Anthony   male  42.0
# 601        3         0             Abbott, Master. Eugene Joseph   male  13.0
# 602        3         0               Abbott, Mr. Rossmore Edward   male  16.0
# 605        3         1             Abelseth, Mr. Olaus Jorgensen   male  25.0
# 606        3         1  Abrahamsson, Mr. Abraham August Johannes   male  20.0
# ...      ...       ...                                       ...    ...   ...
# 1302       3         0                         Yousif, Mr. Wazli   male   NaN
# 1303       3         0                     Yousseff, Mr. Gerious   male   NaN
# 1306       3         0                 Zakarian, Mr. Mapriededer   male  26.5
# 1307       3         0                       Zakarian, Mr. Ortin   male  27.0
# 1308       3         0                        Zimmerman, Mr. Leo   male  29.0
#
#       sibsp  parch            ticket  fare  cabin embarked boat  body  \
# 600       0      0         C.A. 5547   7.5    NaN        S  NaN   NaN
# 601       0      2         C.A. 2673  20.2    NaN        S  NaN   NaN
# 602       1      1         C.A. 2673  20.2    NaN        S  NaN   190
# 605       0      0            348122   7.7  F G63        S    A   NaN
# 606       0      0  SOTON/O2 3101284   7.9    NaN        S   15   NaN
# ...     ...    ...               ...   ...    ...      ...  ...   ...
# 1302      0      0              2647   7.2    NaN        C  NaN   NaN
# 1303      0      0              2627  14.5    NaN        C  NaN   NaN
# 1306      0      0              2656   7.2    NaN        C  NaN   304
# 1307      0      0              2670   7.2    NaN        C  NaN   NaN
# 1308      0      0            315082   7.9    NaN        S  NaN   NaN
#
#                               home.dest  age_computed
# 600                                 NaN          42.0
# 601                 East Providence, RI          13.0
# 602                 East Providence, RI          16.0
# 605                  Perkins County, SD          25.0
# 606   Taalintehdas, Finland Hoboken, NJ          20.0
# ...                                 ...           ...
# 1302                                NaN          29.9
# 1303                                NaN          29.9
# 1306                                NaN          26.5
# 1307                                NaN          27.0
# 1308                                NaN          29.0
#
# [493 rows x 15 columns])

# %%
# Plot how many survived, by gender and class
grid_plot = sns.FacetGrid(titanic, row='gender', col='pclass')
grid_plot.map(sns.regplot, 'survived', 'age',color='.3', fit_reg=False, x_jitter=.3)

# %%
ax = sns.boxplot(titanic.age, groupby=titanic.pclass)
ax.set_title('Age Distribution by class')

# %%
# Who paid the highest Fare in Titanic.  Did they survive?
titanic.sort_index(by='fare', ascending=False)
# Out:
#       pclass  survived                                               name  \
# 183        1         1                             Lesurer, Mr. Gustave J
# 302        1         1                                   Ward, Miss. Anna
# 49         1         1                 Cardeza, Mr. Thomas Drake Martinez
# 50         1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 113        1         1                         Fortune, Miss. Mabel Helen
# ...      ...       ...                                                ...
# 363        2         0                              Campbell, Mr. William
# 384        2         0                     Cunningham, Mr. Alfred Fleming
# 581        2         0                         Watson, Mr. Ennis Hastings
# 410        2         0                   Frost, Mr. Anthony Wood "Archie"
# 1225       3         0                                 Storey, Mr. Thomas
#
#       gender   age  sibsp  parch    ticket   fare        cabin embarked boat  \
# 183     male  35.0      0      0  PC 17755  512.3         B101        C    3
# 302   female  35.0      0      0  PC 17755  512.3          NaN        C    3
# 49      male  36.0      0      1  PC 17755  512.3  B51 B53 B55        C    3
# 50    female  58.0      0      1  PC 17755  512.3  B51 B53 B55        C    3
# 113   female  23.0      3      2     19950  263.0  C23 C25 C27        S   10
# ...      ...   ...    ...    ...       ...    ...          ...      ...  ...
# 363     male   NaN      0      0    239853    0.0          NaN        S  NaN
# 384     male   NaN      0      0    239853    0.0          NaN        S  NaN
# 581     male   NaN      0      0    239856    0.0          NaN        S  NaN
# 410     male   NaN      0      0    239854    0.0          NaN        S  NaN
# 1225    male  60.5      0      0      3701    NaN          NaN        S  NaN
#
#       body                                       home.dest  age_computed
# 183    NaN                                             NaN          35.0
# 302    NaN                                             NaN          35.0
# 49     NaN  Austria-Hungary / Germantown, Philadelphia, PA          36.0
# 50     NaN                    Germantown, Philadelphia, PA          58.0
# 113    NaN                                    Winnipeg, MB          23.0
# ...    ...                                             ...           ...
# 363    NaN                                         Belfast          29.9
# 384    NaN                                         Belfast          29.9
# 581    NaN                                         Belfast          29.9
# 410    NaN                                         Belfast          29.9
# 1225   261                                             NaN          60.5
#
# [1309 rows x 15 columns]

# %%
# Custom Translation of Values and creating new Columns
def gender_map(val):
    if val == 'male':
        return 1
    return 0
titanic['gender_val'] = titanic.gender.map(gender_map)

# %%
titanic.head()

# %%
# Some mistakes I made when learning to work with Pandas
# Don't use Loop to update Dataframe
for k, row in titanic.iterrows():
    if row.gender == 'male':
        titanic.ix[k, 'gender_val'] = 5
    else:
        titanic.ix[k, 'gender_val'] = 6

# %%
titanic.head()

# %%
# Filtering Gotchas
titanic[(titanic.survived == 1) & (titanic.pclass == 1)]

# %%
# Let's now look at Distribution of Age and Survived
# Now look at survived data
g = sns.FacetGrid(titanic, row='gender', col='survived', sharex=True, sharey=True)
g.map(plt.hist, "age")

# %%
# Now, your turn - Can you do some plots with pclass (Passenger Class)
